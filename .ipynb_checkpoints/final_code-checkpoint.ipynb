# %%
import cv2 as cv
import numpy as np
import random
import os
import smtplib
from tensorflow.keras.models import Sequential,load_model
import pywhatkit

# %%
import tensorflow.keras
from PIL import Image, ImageOps
import numpy as np
np.set_printoptions(suppress=True)

# %%
model_hel = tensorflow.keras.models.load_model('final_hel_model.h5')
model_lan = tensorflow.keras.models.load_model('lane_detect_model.h5')
IMG_SIZE = 224
whT = 608
confThreshold =0.7
nmsThreshold= 0.2
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
#### LOAD MODEL
## Coco Names
classesFile='coco.names'
classNames= []
classFile = 'coco.names'
with open(classFile,'rt') as f:
        classNames = f.read().rstrip('\n').split('\n')

# %%
modelConfiguration = 'yolov3.cfg'
modelWeights = 'yolov3.weights'
net = cv.dnn.readNetFromDarknet(modelConfiguration, modelWeights)
net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv.dnn.DNN_TARGET_CPU)

# %%
hel_labels_dict={0:'others',1:'no',2:'yes'}
lan_labels_dict = {0:'others',1:'on',2:'off'}

# %%
li=["digitaldhosth001@gmail.com"]
def mail(li,prediction):
    for dest in li:
        s=smtplib.SMTP('smtp.gmail.com',587)
        s.starttls()
        s.login("rasp283@gmail.com","@123456789@")
        message="the forest caught on fire"+prediction
        s.sendmail("rasp283@gmail.com",dest,message)
        s.quit()

# %%
def msg():
    pywhatkit.sendwhatmsg_instantly('+91 phn no','hi dady')

# %%
def call_model(image,model,dic):
    labels = dic
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
    
    #resize the image to a 224x224 with the same strategy as in TM2:
    #resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.ANTIALIAS)

    #turn the image into a numpy array
    image_array = np.asarray(image)

    # display the resized image
   # image.show()

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1

    # Load the image into the array
    data[0] = normalized_image_array

    # run the inference
    result = model.predict(data)
    print(result)
    result=np.argmax(result,axis=1)[0]
    print(result)
    prediction=labels[result]
    print(prediction)
    return prediction

# %%
def save_img(img2):
    n = random.randint(0,100000)
    n = str(n)
    cv.imwrite('hel/'+n+".jpg",img2)

# %%
def findObjects(outputs,img):

    hT, wT, cT = img.shape
    bbox = []
    classIds = []
    confs = []
    for output in outputs:
        for det in output:
            scores = det[5:]
            classId = np.argmax(scores)
            confidence = scores[classId]
            if confidence > confThreshold:
                w,h = int(det[2]*wT) , int(det[3]*hT)
                x,y = int((det[0]*wT)-w/2) , int((det[1]*hT)-h/2)
                bbox.append([x,y,w,h])
                classIds.append(classId)
                confs.append(float(confidence))

    indices = cv.dnn.NMSBoxes(bbox, confs, confThreshold, nmsThreshold)

    for i in indices:
        i = i[0]
        box = bbox[i]
        x, y, w, h = box[0], box[1], box[2], box[3]
  
        
        if classNames[classIds[i]].upper() =="MOTORCYCLE":
            hel_img = img[y-200:y+h-100, x:x+w+2]
            lan_img = img[y+20:y+h+40, x:x+w+2]
            save_img(hel_img)
#             save_img(lan_img)
                        
            cv.imwrite("two/two_lan.jpg",lan_img)
            cv.imwrite("two/hel_lan.jpg",hel_img)
            
            hel_img = Image.open('two/two_lan.jpg')
            lan_img = Image.open('two/hel_lan.jpg')
            
            hel_prediction = call_model(hel_img,model_hel,hel_labels_dict)
            
            lan_prediction = call_model(lan_img,model_lan,lan_labels_dict)
            
            if hel_prediction=='no':
                print('not wear helmet mail sent')
                prediction_hel = 'person has not ware the helmet'
                cv.rectangle(img,(x,y-200),(x+w+100,y+h),(255,0,255), 2)
                cv.putText(img,prediction_hel,
                     (x, y), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
                #mail(li,prediction_hel)
                #msg()
            elif hel_prediction=='yes':
                print('person has ware his helmet')
                prediction_hel = 'person has ware the helmet'
                
                cv.rectangle(img,(x,y-200),(x+w,y+h-100),(255,0,255), 2)
                cv.putText(img,prediction_hel,
                     (x, y), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
                
                
            elif hel_prediction=='others':
                 print('others')
            
            if lan_prediction=='on':
                
                print('bike is on the lane: mail is sent')
                
                prediciton_line = 'on the lane'
                
                cv.rectangle(img,(x,y),(x+w,y+h),(255,0,255), 2)
                cv.putText(img,prediciton_line,
                     (x, y), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
#                 msg()
#                 mail(li,prediction_line)
            
                
                
            elif lan_prediction=='off':
                
                print('bike is not on the lane')
                
                prediciton_line = 'of the lane'
                
                
                cv.rectangle(img,(x,y),(x+w,y+h),(255,0,255), 2)
                cv.putText(img,prediciton_line,
                     (x, y), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
                
            elif lan_prediction=='others':
                
                print('others')
            
         
            
            
        elif classNames[classIds[i]].upper() =="CAR":
            img2 = img[y+100:y+h+40, x:x+w+10]
            cv.imwrite("four/car_lan_img.jpg",img2)
#             save_img(img2)
            
            car_img = Image.open('four/car_lan_img.jpg')
            car_lan_pred = call_model(car_img,model_lan,lan_labels_dict)
            
            
            if car_lan_pred=='on':
                print('car is on the lane mail is sent')
                prediction_line = 'car is on the lane'
                cv.rectangle(img,(x, y), (x+w,y+h), (255, 0 , 255), 2)
                cv.putText(img,prediction_line,
                    (x, y-10), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)    

                
            elif car_lan_pred=='off':
                print('car is not on the lane')
                prediction_line = 'car is not on the lane'
            
                cv.rectangle(img,(x, y), (x+w,y+h), (255, 0 , 255), 2)
           
                cv.putText(img,prediction_line,
                    (x, y-10), cv.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)  
            elif car_lan_pred=='others':
                print('others')

# %%
path = 'C:/Users/LENOVO/Desktop/traffic_voilation/images/final_traffic_detection'
img_name = 'test.jpg'   
img = cv.imread(os.path.join(path,img_name))
blob = cv.dnn.blobFromImage(img, 1/ 255, (whT, whT), [0, 0, 0], 1, crop=False)
net.setInput(blob)
layersNames = net.getLayerNames()
outputNames = [(layersNames[i[0] - 1]) for i in net.getUnconnectedOutLayers()]

outputs = net.forward(outputNames)
#     print(outputs)
findObjects(outputs,img)

cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# [[0.00001725 0.00009088 0.9998919 ]]
# 2
# off
# car is not on the lane
# [[0.00001603 0.00000334 0.9999807 ]]
# 2
# off
# car is not on the lane
# [[0.9956226  0.00029361 0.00408383]]
# 0
# others
# [[0.26809534 0.7299217  0.00198292]]
# 1
# on
# others
# bike is on the lane: mail is sent
# [[0.9999615  0.00000803 0.0000305 ]]
# 0
# others
# [[0.8939181  0.03839529 0.06768655]]
# 0
# others
# others
# others
# [[0.7945729  0.00019509 0.20523193]]
# 0
# others
# [[0.8137077  0.1538021  0.03249018]]
# 0
# others
# others
# others
# [[0.99938    0.00015856 0.00046143]]
# 0
# others
# [[0.06188273 0.00706848 0.9310488 ]]
# 2
# off
# others
# bike is not on the lane
# [[0.9998547  0.00000122 0.00014405]]
# 0
# others
# others
# [[0.9996351  0.00007492 0.00028993]]
# 0
# others
# others
